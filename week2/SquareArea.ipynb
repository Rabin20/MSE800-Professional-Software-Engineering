# %%
# Importing math module for square function
import math

# Input length and width (could be negative or decimal)
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

# Use abs to make sure dimensions are positive
length = abs(length)
width = abs(width)

# To Calculate area (length * width)
area = length * width

# Use square just for illustration (e.g., side^2 for a square area example)
# We'll calculate a square area from the average of length and width
avg_side = (length + width) / 2
square_area = math.pow(avg_side, 2)

# Round the results
area_rounded = round(area, 2)
square_area_rounded = round(square_area, 2)

# Display results
print("Rounded Area of Rectangle:", area_rounded)
print("Rounded Square Area from Avg Side:", square_area_rounded)
# Out:
# Enter the length of the rectangle: 2
# Enter the width of the rectangle: 2
# Rounded Area of Rectangle: 4.0
# Rounded Square Area from Avg Side: 4.0
